# %% [markdown]
# <a href="https://colab.research.google.com/github/poontamil-0807/CO2-emission-pred/blob/main/appliance_energy_pred.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv('/content/appliance_energy.csv')

# %%
print(df.head())
# Out:
#    Temperature (°C)  Energy Consumption (kWh)
# 0         22.490802                  2.292604
# 1         34.014286                  3.251925
# 2         29.639879                  3.009868
# 3         26.973170                  1.703533
# 4         18.120373                  1.702201

# %%
print(df.isnull().sum())
df = df.dropna()
# Out:
# Temperature (°C)            0
# Energy Consumption (kWh)    0
# dtype: int64

# %%
X = df[['Temperature (°C)']]
y = df['Energy Consumption (kWh)']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=40)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([1.86035492, 2.88980011, 2.26479423, 1.97374543, 2.81462533,
#        3.29427034, 1.87071283, 2.77817348, 2.40481956, 3.05724513,
#        2.89080584, 1.92776517, 2.53899595, 2.5292015 , 2.71231699,
#        2.54686769, 2.22138375, 3.25897098, 2.8546514 , 2.94315446])

# %%
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
r2 = r2_score(y_test, y_pred)
print(f"R-Squared: {r2}")
# Out:
# Mean Squared Error: 0.15688560358921597
# R-Squared: 0.6823667793914241
